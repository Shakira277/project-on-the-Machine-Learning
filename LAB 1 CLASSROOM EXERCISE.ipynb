# %% [markdown]
# EDUNET FOUNDATION-CLASSROOM EXERCISE NOTEBOOK

# %% [markdown]
# LAB-1 First neural network with keras

# %%
from numpy import loadtxt
from tensorflow import keras

from tensorflow.keras.model import sequetial
from tensorflow.keras.layer import dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 from numpy import loadtxt
# ----> 2 from tensorflow import keras
#       4 from tensorflow.keras.model import sequetial
#       5 from tensorflow.keras.layer import dense
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 48.7/48.7 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/390.3 MB 5.3 MB/s eta 0:01:14
#    ---------------------------------------- 0.6/390.3 MB 6.4 MB/s eta 0:01:02
#    ---------------------------------------- 1.0/390.3 MB 7.8 MB/s eta 0:00:51
#    ---------------------------------------- 1.2/390.3 MB 6.9 MB/s eta 0:00:57
#    ---------------------------------------- 1.5/390.3 MB 6.4 MB/s eta 0:01:01
#    ---------------------------------------- 1.9/390.3 MB 7.0 MB/s eta 0:00:56
#    ---------------------------------------- 2.4/390.3 MB 7.6 MB/s eta 0:00:51
#    ---------------------------------------- 3.0/390.3 MB 8.1 MB/s eta 0:00:49
#    ---------------------------------------- 3.4/390.3 MB 8.1 MB/s eta 0:00:48
# ...
